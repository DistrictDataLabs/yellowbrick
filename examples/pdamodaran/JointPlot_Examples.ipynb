# %%
# %matplotlib inline

# %%
import sys
#sys.path.append("../../..")
sys.path.insert(0, '/Users/Copper/git/yellowbrick')

# %%
from tests.dataset import DatasetMixin as dm
concrete = dm.load_data('concrete')
from yellowbrick.features import JointPlotVisualizer

import matplotlib as mpl
import matplotlib.pyplot as plt

# Load the data from the fixture
X = concrete['cement']
y = concrete['strength']
feature = 'cement'
target = 'strength'

# %%
#example 1
_, ax = plt.subplots()
visualizer = JointPlotVisualizer(ax=ax, feature=feature, target=target, joint_plot="hex")


visualizer.fit(X, y)
visualizer.poof()

# %%
#example 2

fig = plt.figure()
ax = fig.add_subplot()
visualizer = JointPlotVisualizer(ax=ax, feature=feature, target=target, joint_plot="hex")


visualizer.fit(X, y)
visualizer.poof()
