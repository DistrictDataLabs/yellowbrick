# %%
from yellowbrick.datasets import load_game, load_spam
from yellowbrick.classifier import ClassificationReport, ConfusionMatrix, ROCAUC, DiscriminationThreshold, DiscriminationThreshold, DiscriminationThreshold
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from yellowbrick.datasets import load_spam


import matplotlib
# %matplotlib inline

# %%
classifiers = [DiscriminationThreshold, DiscriminationThreshold, DiscriminationThreshold, DiscriminationThreshold, DiscriminationThreshold, DiscriminationThreshold]

X, y = load_spam()
label_enc = LabelEncoder()
y = label_enc.fit_transform(y)
X_train, X_test, y_train, y_test = train_test_split(X, y)


# Normal YB Call on unfit data
reg = LogisticRegression(multi_class="auto", solver="liblinear") #unfitted Classifier
viz = DiscriminationThreshold(reg)
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.poof()
# Out:
# /Users/lgray/anaconda3/envs/yellowbrick/lib/python3.7/site-packages/sklearn/svm/base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
# Fit a classifier
clf = LogisticRegression(multi_class="auto", solver="liblinear")
clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.9165217391304348

# %% [raw]
# Call fit, score, poof on a fitted scikit-learn classifier where the visualizer’s `is_fitted` param is True
# Call fit, score, poof on a fitted scikit-learn classifier where the visualizer’s `is_fitted` param is False
# Call fit, score, poof on a fitted scikit-learn classifier where the visualizer’s `is_fitted` param is `auto` (default)
#
# Call fit, score, poof on an unfitted scikit-learn classifier where the visualizer’s `is_fitted` param is True
# Call fit, score, poof on an unfitted scikit-learn classifier where the visualizer’s `is_fitted` param is False
# Call fit, score, poof on an unfitted scikit-learn classifier where the visualizer’s `is_fitted` param is `auto`  (default)
#
# Call fit, score, poof on a fitted scikit-learn classifier where `encoder` is a dictionary (no `classes`)
# Call fit, score, poof on a fitted scikit-learn classifier where `encoder` is a LabelEncoder (no `classes`)
# Call fit, score, poof on a fitted scikit-learn classifier where `classes` are passed to the visualizer as a list (no `encoder`)
# Call fit, score, poof on a fitted scikit-learn classifier where `classes` are passed to the visualizer as a list and `encoder` is a dictionary
# Call fit, score, poof on a fitted scikit-learn classifier where `classes` are passed to the visualizer as a list and `encoder` is a LabelEncoder
#
# Call fit, score, poof on an unfitted scikit-learn classifier where `encoder` is a dictionary (no `classes`)
# Call fit, score, poof on an unfitted scikit-learn classifier where `encoder` is a LabelEncoder (no `classes`)
# Call fit, score, poof on an unfitted scikit-learn classifier where `classes` are passed to the visualizer as a list (no `encoder`)
# Call fit, score, poof on an unfitted scikit-learn classifier where `classes` are passed to the visualizer as a list and `encoder` is a dictionary
# Call fit, score, poof on an unfitted scikit-learn classifier where `classes` are passed to the visualizer as a list and `encoder` is a LabelEncoder

# %%
print("\n","Run on fitted classifier where is_fitted is [True, False, 'auto']","\n")

viz = DiscriminationThreshold(clf, is_fitted=True)
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.poof()

viz = DiscriminationThreshold(clf, is_fitted=False)
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.poof()

viz = DiscriminationThreshold(clf, is_fitted='auto')
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.poof()

print("\n", "Run on un_fitted classifier where is_fitted is [True, False, 'auto']","\n")

viz = DiscriminationThreshold(reg, is_fitted=True)
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.poof()

viz = DiscriminationThreshold(reg, is_fitted=False)
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.poof()

viz = DiscriminationThreshold(reg, is_fitted='auto')
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.poof()

print("\n", "Run on fitted classifier where encoder is a dict \(no classes\)","\n")
viz = DiscriminationThreshold(clf, encoder={0:'not spam', 1:'spam'})
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.poof()

print("# Call fit, score, poof on an unfitted scikit-learn classifier where `encoder` is a LabelEncoder (no `classes`)")
from sklearn.preprocessing import LabelEncoder
viz = DiscriminationThreshold(clf, encoder=label_enc)
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.poof()

print("# Call fit, score, poof on a fitted scikit-learn classifier where `classes` are passed to the visualizer as a list (no `encoder`)")
viz = DiscriminationThreshold(clf, classes=['not spam','spam'])
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.poof()

print("# Call fit, score, poof on a fitted scikit-learn classifier where `classes` are passed to the visualizer as a list and `encoder` is a dictionary")
viz = DiscriminationThreshold(clf, classes=['not spam','spam'], encoder={0:'not spam', 1:'spam'})
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.poof()

print("# Call fit, score, poof on a fitted scikit-learn classifier where `classes` are passed to the visualizer as a list and `encoder` is a LabelEncoder")
viz = DiscriminationThreshold(clf, classes=['not spam','spam'], encoder=label_enc)
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.poof()

print("\n", "Run on unfitted classifier where encoder is a dict \(no classes\)","\n")
viz = DiscriminationThreshold(reg, encoder={0:'not spam', 1:'spam'})
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.poof()

print("# Call fit, score, poof on an unfitted scikit-learn classifier where `encoder` is a LabelEncoder (no `classes`)")
from sklearn.preprocessing import LabelEncoder
viz = DiscriminationThreshold(reg, encoder=label_enc)
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.poof()

print("# Call fit, score, poof on a unfitted scikit-learn classifier where `classes` are passed to the visualizer as a list (no `encoder`)")
viz = DiscriminationThreshold(reg, classes=['not spam','spam'])
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.poof()

print("# Call fit, score, poof on a unfitted scikit-learn classifier where `classes` are passed to the visualizer as a list and `encoder` is a dictionary")
viz = DiscriminationThreshold(reg, classes=['not spam','spam'], encoder={0:'not spam', 1:'spam'})
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.poof()

print("# Call fit, score, poof on a unfitted scikit-learn classifier where `classes` are passed to the visualizer as a list and `encoder` is a LabelEncoder")
viz = DiscriminationThreshold(reg, classes=['not spam','spam'], encoder=label_enc)
viz.fit(X_train, y_train)
viz.score(X_test, y_test)
viz.poof()
# Out:
#  Run on fitted classifier where is_fitted is [True, False, 'auto']
# /Users/lgray/anaconda3/envs/yellowbrick/lib/python3.7/site-packages/sklearn/svm/base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/lgray/anaconda3/envs/yellowbrick/lib/python3.7/site-packages/sklearn/svm/base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/lgray/anaconda3/envs/yellowbrick/lib/python3.7/site-packages/sklearn/svm/base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/lgray/anaconda3/envs/yellowbrick/lib/python3.7/site-packages/sklearn/svm/base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
# ...
